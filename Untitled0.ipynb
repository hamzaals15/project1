# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzaals15/project1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mesaj = 'Beyan'
mesaj2 = 'Hamza'
print(len(mesaj + mesaj2))
# Out:
# 10

# %%
mesaj = 'merhaba'
mesaj = mesaj.upper()
print(mesaj)
mesaj = mesaj.lower()
print(mesaj)
mesaj = mesaj.capitalize()
print(mesaj)
# Out:
# MERHABA
# merhaba
# Merhaba

# %%
mesaj = 'Hello Kity'
print(mesaj.startswith('hello Kity'))
# Out:
# False

# %%
mesaj = 'people'
print(mesaj.endswith('ple'))
# Out:
# True

# %%
mesaj = 'be'
mesaj2 = 'kind'
print('be' + ' ' + mesaj2)
# Out:
# be kind

# %%
mesaj = 'merhaba'
mesaj2 = 'gençler'
print(mesaj + ' ' + mesaj2)
# Out:
# merhaba gençler

# %%
print('hamza '*10)
# Out:
# hamza hamza hamza hamza hamza hamza hamza hamza hamza hamza

# %%
isim = 'hamza'
yaş = '15'
print('{} , {} yaşındadır'.format(isim,yaş))
# Out:
# hamza , 15 yaşındadır

# %%
isim = 'hamza'
mesaj = 'hello'
print('{} {} dedi...'.format(isim,mesaj))

print(f'{isim} {mesaj} dedi..')
# Out:
# hamza hello dedi...
# hamza hello dedi..?

# %%
isim = 'hamza'
mesaj = 'merhaba'
print(f'{isim} {mesaj} dedi')
# Out:
# hamza merhaba dedi

# %%
isim = 'hamza'
mesaj = 'merhaba'
print(f'{isim} {mesaj} dedi')
# Out:
# hamza merhaba dedi

# %%
isim = 'hamza'
yaş = '15'
print(f'{isim} {yaş} yaşındadır')
# Out:
# hamza 15 yaşındadır

# %%
print('''merhaba
dünya''')
# Out:
# merhaba
# dünya

# %%
print('ali\'nin evi')
# Out:
# ali'nin evi

# %%
print('merhaba\n\n\ndünya')
# Out:
# merhaba
#
#
# dünya

# %%
print('merhaba\t\t\t\tdünya')
# Out:
# merhaba				dünya

# %%
mesaj = 'merhaba'
mesaj2 = 'dünya'
print( mesaj + ' ' +  mesaj2 )
# Out:
# merhaba dünya

# %%
sayı1 = 5
sayı2 = 3.4

# Convert sayı2 to a float
sayı2_float = float(sayı2)

print(type(sayı2_float))
# Out:
# <class 'float'>

# %%
sayı1 = 9
sayı2 = 3.1
print(type(sayı1))
print(type(sayı2))
# Out:
# <class 'int'>
# <class 'float'>

# %%
sayı1 = 5 ** 100

sayı2 = 22 / 4

print(sayı2)
# Out:
# 5.5

# %%
sayı1 = 8
sayı2 = 3
sayı3 = 2.567890

print(sayı1 + sayı2)
print(sayı1 - sayı2)
print(sayı1 * sayı2)
print(sayı1 / sayı2)
print(sayı1 // sayı2)
print(sayı1 ** sayı2)
print(abs(sayı2 - sayı1))
print(round(sayı1 / sayı2))
print(round(sayı3))
print(round(sayı3,3))
# Out:
# 11
# 5
# 24
# 2.6666666666666665
# 2
# 512
# 5
# 3
# 3
# 2.568

# %%
print(3 == 5)
print(3 != 5)
# Out:
# False
# True

# %%
sayı1 = 30
sayı2= 93
print(sayı1 == sayı2)
print(sayı1 < sayı2)
print(sayı1 > sayı2)
print(sayı1 <= sayı2)
print(sayı1 >= sayı2)
print(sayı1 != sayı2)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a = 1
b = a
a = 5
print(b)
# Out:
# 1

# %%
sayı1 = '100'
sayı2 = 100
sayı3 = int(sayı1)

print(sayı1 == sayı2)
print(sayı3 == sayı2)
# Out:
# False
# True

# %%
sayı1 = '100dfgh'
sayı2 = int(sayı1)
print(sayı3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2388/883530617.py in <cell line: 0>()
#       1 sayı1 = '100dfgh'
# ----> 2 sayı2 = int(sayı1)
#       3 print(sayı3)
#
# ValueError: invalid literal for int() with base 10: '100dfgh'

# %%
sayı1 = int(3.9)
print(sayı1)
# Out:
# 3

# %%
sayı1 = 100
sayı2 = str(sayı1)
print(type(sayı2))
# Out:
# <class 'str'>

# %%
b = 3
b /= 2
print(b)
# Out:
# 1.5

# %%
sayı1 = 2.45678
print(round(sayı1,3))
# Out:
# 2.457

# %%
renkler = ['yeşil','mavi','kırmızı','siyah','beyaz']

print(type(renkler))
print(renkler)
print(len(renkler))
print(renkler[3])
print(renkler[3:5])
print(renkler[:])
print(renkler[::2])
print(renkler[1:5:3])
# Out:
# <class 'list'>
# ['yeşil', 'mavi', 'kırmızı', 'siyah', 'beyaz']
# 5
# siyah
# ['siyah', 'beyaz']
# ['yeşil', 'mavi', 'kırmızı', 'siyah', 'beyaz']
# ['yeşil', 'kırmızı', 'beyaz']
# ['mavi', 'beyaz']

# %%
renkler = ['yeşil','mavi','kırmızı','siyah','beyaz']

print(renkler)

renkler.append('gri')

print(renkler)
# Out:
# ['yeşil', 'mavi', 'kırmızı', 'siyah', 'beyaz']
# ['yeşil', 'mavi', 'kırmızı', 'siyah', 'beyaz', 'gri']

# %%
renkler = ['yeşil,kırmızı,']
print(renkler)
